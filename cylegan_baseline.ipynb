# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 71.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 88.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 93.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 111.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 73.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 120.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 97.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 112.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 92.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 99.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 77.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 74.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 114.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 122.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 123.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 84.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 113.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 78.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 86.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 121.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 91.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 118.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 79.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 115.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 70.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 124.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 96.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 85.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 116.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 76.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 117.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 72.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 89.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 87.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 94.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 83.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 119.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 98.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 90.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 100.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 125.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 95.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 75.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 90.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 100.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 125.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 95.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 75.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 71.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 88.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 93.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 111.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 73.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 120.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 97.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 112.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 92.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 99.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 77.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 74.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 114.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 122.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 123.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 84.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 113.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 78.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 86.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 121.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 91.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 118.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 79.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 115.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 70.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 124.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 96.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 85.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 116.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 76.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 117.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 72.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 89.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 87.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 94.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 83.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 119.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 98.png

# %%
#Import all the required libraries
import os
from os import listdir
import numpy as np
from numpy import asarray
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import tensorflow as tf
strategy = tf.distribute.MirroredStrategy()
# Out:
# 2022-04-11 07:46:48.249952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:48.394381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:48.395436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:48.400553: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-11 07:46:48.402195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:48.403559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:48.404572: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:50.585718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:50.586876: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:50.587947: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 07:46:50.588973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 1

# %%
# load and resize images
def load_images(path, size=(256,256)):
    data_list = list()
    
    for filename in listdir(path):     
        pixels = load_img(path + filename, target_size=size)
        # convert to numpy array
        pixels = img_to_array(pixels)
        # store the data
        data_list.append(pixels)
    return asarray(data_list)

# %%
import tensorflow as tf
tr1_data = load_images('/kaggle/input/d/jaquelinenoonan/mritraint1/') #write your code to create the dataset from image directory
tr1_data = tf.image.rgb_to_grayscale(tr1_data) #convert to grayscale
tr1= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr1_data))
tr1
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
tr2_data = load_images('/kaggle/input/d/jaquelinenoonan/mritraint2/') #write your code to create the dataset from image directory
tr2_data = tf.image.rgb_to_grayscale(tr2_data) #convert to grayscale
tr2= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr2_data))
tr2
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
# image preprocess
BUFFER_SIZE = 1000
BATCH_SIZE = 1

# normalizing the images to [-1, 1]
def normalize(image):
    image =  tf.cast(image, tf.float32)
    image= (image / 127.5) - 1 
    return image

def preprocess_image_train(image):
#     image = tf.image.random_flip_left_right(image)
    image = normalize(image)   
    return image


def preprocess_image_test(image):
    image = normalize(image)   
    return image

# %%
# process both classes of MRI images
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

tr1 = tr1.map(preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)
tr2 = tr2.map(preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)

sample_tr1 = next(iter(tr1))
sample_tr2 = next(iter(tr2))

tr1 = tr1.shuffle(BUFFER_SIZE)
tr2 = tr2.shuffle(BUFFER_SIZE)


# tr1 = tr1 .map(preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# tr2 = tr2 .map(preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# sample_tr1 = next(iter(tr1))
# sample_tr2 = next(iter(tr2))
# Out:
# 2022-04-11 07:46:53.133016: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-04-11 07:46:53.172863: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2022-04-11 07:46:53.202493: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
plt.title('tr1')
plt.imshow(sample_tr1[0].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')

# %%
plt.title('tr2')
plt.imshow(sample_tr2[0].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')

# %%
class InstanceNormalization(tf.keras.layers.Layer):
    def __init__(self, epsilon=1e-5):
        super(InstanceNormalization, self).__init__()
        self.epsilon = epsilon
    def build(self, input_shape):
        self.scale = self.add_weight(
            name='scale',
            shape=input_shape[-1:],
            initializer=tf.random_normal_initializer(1., 0.02),
            trainable=True)
        self.offset = self.add_weight(
            name='offset',
            shape=input_shape[-1:],
            initializer='zeros',
            trainable=True)
    def call(self, x):
        mean, variance = tf.nn.moments(x, axes=[1, 2], keepdims=True)
        inv = tf.math.rsqrt(variance + self.epsilon)
        normalized = (x - mean) * inv
        return self.scale * normalized + self.offset

def downsample(filters, size, apply_norm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    result = tf.keras.Sequential()
    result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                      kernel_initializer=initializer, use_bias=False))
    if apply_norm:
        result.add(InstanceNormalization())
    result.add(tf.keras.layers.LeakyReLU())
    return result

def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    result = tf.keras.Sequential()
    result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2, padding='same',
                                               kernel_initializer=initializer, use_bias=False))
    result.add(InstanceNormalization())
    if apply_dropout:
        result.add(tf.keras.layers.Dropout(0.5))
    result.add(tf.keras.layers.ReLU())
    return result

# %%
import keras

# %%
def unet_generator():
   
    down_stack = [
      downsample(64, 4, apply_norm=False), 
      downsample(128, 4), 
      downsample(256, 4),  
      downsample(512, 4),  
#       downsample(512, 4), 
#       downsample(512, 4),  
#       downsample(512, 4),  
      downsample(512, 4),  
    ]
                  #create a stack of downsample models
    up_stack = [
      upsample(512, 4, apply_dropout=True),  
#       upsample(512, 4, apply_dropout=True),  
#       upsample(512, 4, apply_dropout=True),  
#       upsample(512, 4),  
      upsample(256, 4),  
      upsample(128, 4),  
      upsample(64, 4),  
               ] #create a stack of upsample models
        
    initializer = tf.random_normal_initializer(0., 0.02)
    last = tf.keras.layers.Conv2DTranspose(1, 4, strides=2, padding='same', kernel_initializer=initializer,
                                           activation='tanh') 
#     concat = tf.keras.layers.Concatenate()
    inputs = tf.keras.layers.Input(shape=[None, None, 1])
    x = inputs
    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = tf.keras.layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %%
with strategy.scope():
    generator_g = unet_generator() #initialise the generator
    generator_f = unet_generator() #initialise the generator

# %%
generator_g.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, None, None, 6 1024        input_1[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, None, None, 1 131328      sequential[0][0]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, None, None, 2 524800      sequential_1[0][0]
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, None, None, 5 2098176     sequential_2[0][0]
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, None, None, 5 4195328     sequential_3[0][0]
# __________________________________________________________________________________________________
# sequential_5 (Sequential)       (None, None, None, 5 4195328     sequential_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 1 0           sequential_5[0][0]
#                                                                  sequential_3[0][0]
# __________________________________________________________________________________________________
# sequential_6 (Sequential)       (None, None, None, 2 4194816     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 5 0           sequential_6[0][0]
#                                                                  sequential_2[0][0]
# __________________________________________________________________________________________________
# sequential_7 (Sequential)       (None, None, None, 1 1048832     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 2 0           sequential_7[0][0]
#                                                                  sequential_1[0][0]
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, None, None, 6 262272      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           sequential_8[0][0]
#                                                                  sequential[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, None, None, 1 2049        concatenate_3[0][0]
# ==================================================================================================
# Total params: 16,653,953
# Trainable params: 16,653,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    inp = tf.keras.layers.Input(shape=[None, None, 1], name='input_image')
    x = inp
    down1 = downsample(64, 4,  False)(x)  #write your code to downsample X
    down2 = downsample(128, 4)(down1)     #write your code to downsample down1
    down3 = downsample(256, 4)(down2)     #write your code to downsample down2
    zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = tf.keras.layers.Conv2D(512, 4, strides=1, kernel_initializer=initializer,
                                  use_bias=False)(zero_pad1) # (bs, 31, 31, 512)
    norm1 = InstanceNormalization()(conv)
    leaky_relu = tf.keras.layers.LeakyReLU()(norm1)
    zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)
    last = tf.keras.layers.Conv2D(1, 4, strides=1, kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)
  
    return tf.keras.Model(inputs=inp, outputs=last) #create the model using input & output layer

# %%
with strategy.scope():
    discriminator_x = discriminator() #initialise the discriminator
    discriminator_y = discriminator() #initialise the discriminator

# %%
# to_tr2 = generator_g(sample_tr1)
# to_tr1 = generator_f(sample_tr2)
# plt.figure(figsize=(8, 8))
# contrast = 8

# imgs = [sample_tr1, to_tr2, sample_tr2, to_tr1]
# title = ['tr1', 'To tr2', 'tr2', 'To tr1']

# for i in range(len(imgs)):
#     plt.subplot(2, 2, i+1)
#     plt.title(title[i])
#     if i % 2 == 0:
#         plt.imshow(imgs[i][0].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
#     else:
#         plt.imshow(imgs[i][0].numpy()[:, :, 0] * 0.5 * contrast + 0.5, cmap='gray')
# plt.show()

# %%
LAMBDA = 10

# %%
# Using Binarycross entropy with logits true
loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
with strategy.scope():
    # calculating discriminator loss by summing the real and generated
    def discriminator_loss(real, generated):
        real_loss = loss_obj(tf.ones_like(real), real) #write your code here
        generated_loss = loss_obj(tf.zeros_like(generated), generated) #write your code here
        total_disc_loss = real_loss + generated_loss #write your code here
        return total_disc_loss * 0.5

with strategy.scope():
    def generator_loss(generated):
        return loss_obj(tf.ones_like(generated), generated)

with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image)) #write your code here
        return LAMBDA * loss1

# %%
EPOCHS = 300 #"Your Number of Epochs Here"

# %%
with strategy.scope():
# Optimizer with learning rate 0.0001 for generator and discriminator
    generator_g_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)
    generator_f_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)

    discriminator_x_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)
    discriminator_y_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)

# %%
# checkpoint_path = './checkpoints'  
# ckpt = tf.train.Checkpoint(generator_g=generator_g,
#                            generator_f=generator_f,
#                            discriminator_x=discriminator_x,
#                            discriminator_y=discriminator_y,
#                            generator_g_optimizer=generator_g_optimizer,
#                            generator_f_optimizer=generator_f_optimizer,
#                            discriminator_x_optimizer=discriminator_x_optimizer,
#                            discriminator_y_optimizer=discriminator_y_optimizer)

# ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=EPOCHS)

# # if a checkpoint exists, restore the latest checkpoint.
# if ckpt_manager.latest_checkpoint:
#     ckpt.restore(ckpt_manager.latest_checkpoint)
#     print ('Latest checkpoint restored!!')

# %%
def generate_images(model, test_input, expected_output):
    prediction = model(test_input)
    plt.figure(figsize=(10, 10))
    display_list = [test_input[0], prediction[0], expected_output[0]]
    title = ['Input Image', 'Predicted Image', 'Expected Image']
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off')
    plt.show()

# %%
# define the metrics to evaluate the difference between generated image and target image
import numpy
import math

def psnr(img1, img2):
    mse = numpy.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

def mae(img1, img2):
    mae1 = numpy.mean( abs(img1 - img2) )
    return mae1

def metrics(model, test_input, expected_output):
    prediction = model(test_input)
    m_psnr = psnr(prediction[0], expected_output[0])
    m_mae = mae(prediction[0], expected_output[0])
    return (m_psnr, m_mae)

# %%
with strategy.scope():
    @tf.function
    def train_step(real_x, real_y):
    # persistent is set to True because the tape is used more than
    # once to calculate the gradients.
        with tf.GradientTape(persistent=True) as tape:
            # Generator G translates X -> Y
            # Generator F translates Y -> X.
            fake_y = generator_g(real_x, training=True)  #write your code to generate images using Generator_g on real_x
            cycled_x = generator_f(fake_y, training=True) #write your code to generate images susiing Generator_f on fake_y

            fake_x =  generator_f(real_y, training=True) #write your code to generate images using Generator_f on real_y
            cycled_y = generator_g(fake_x, training=True) #write your code to generate images using Generator_g on fake_x

            # same_x and same_y are used for identity loss.
#             same_x = generator_f(real_x, training=True) #write your code to generate images using Generator_f on real_x
#             same_y = generator_g(real_y, training=True) #write your code to generate images using Generator_g on real_y

            disc_real_x =  discriminator_x(real_x, training=True) #write your code to discriminate images using Discriminator_x on real_x
            disc_real_y = discriminator_y(real_y, training=True) #write your code to discriminate images using Discriminator_y on real_y

            disc_fake_x = discriminator_x(fake_x, training=True) #write your code to discriminate images using Discriminator_x on fake_x
            disc_fake_y = discriminator_y(fake_y, training=True) #write your code to discriminate images using Discriminator_y on fake_y

            # calculate the loss
            gen_g_loss = generator_loss(disc_fake_y) # calculate the generator_loss for disc_fake_
            gen_f_loss = generator_loss(disc_fake_x) # calculate the generator_loss for disc_fake_X 

#             style_g_loss = tf.norm(generator_g(real_x - fake_y, training=True), ord=2)
#             style_f_loss = tf.norm(generator_f(real_y - fake_x, training=True), ord=2)
            
#             identity_g_loss = identity_loss(real_y, same_y)
#             identity_f_loss = identity_loss(real_x, same_x)
        
            total_cycle_loss = calc_cycle_loss(real_x, cycled_x) + calc_cycle_loss(real_y, cycled_y)
     #calculate the total cycle loss

            # Total generator loss = adversarial loss + cycle loss
            total_gen_g_loss = gen_g_loss + total_cycle_loss
            total_gen_f_loss = gen_f_loss + total_cycle_loss 
        

            disc_x_loss = discriminator_loss(disc_real_x, disc_fake_x) # calculate the discriminator_loss for disc_fake_x wrt disc_real_x
            disc_y_loss = discriminator_loss(disc_real_y, disc_fake_y) # calculate the discriminator_loss foor disc_fake_y wrt disc_real_y

        # Calculate the gradients for generator and discriminator
        generator_g_gradients = tape.gradient(total_gen_g_loss, 
                                            generator_g.trainable_variables) #write your code here
        generator_f_gradients = tape.gradient(total_gen_f_loss, 
                                            generator_f.trainable_variables) #write your code here

        discriminator_x_gradients = tape.gradient(disc_x_loss, 
                                                discriminator_x.trainable_variables) #write your code here
        discriminator_y_gradients = tape.gradient(disc_y_loss, 
                                                discriminator_y.trainable_variables)
     #write your code here

        # Apply the gradients to the optimizer

        generator_g_optimizer.apply_gradients(zip(generator_g_gradients, 
                                                generator_g.trainable_variables))

        generator_f_optimizer.apply_gradients(zip(generator_f_gradients, 
                                                generator_f.trainable_variables))

        discriminator_x_optimizer.apply_gradients(zip(discriminator_x_gradients,
                                                    discriminator_x.trainable_variables))

        discriminator_y_optimizer.apply_gradients(zip(discriminator_y_gradients,
                                                    discriminator_y.trainable_variables)) #write your code here

# %%
PSNR = []
MAE = []
for epoch in range(EPOCHS):
    for image_x, image_y in tf.data.Dataset.zip((tr1, tr2)):
        train_step(image_x, image_y)
#     generate_images(generator_g, sample_tr1, sample_tr2)
    img_metrics = metrics(generator_g, sample_tr1, sample_tr2)
    print('Epoch', epoch, 'PSNR metrics:', img_metrics[0], 'MAE metrics:', img_metrics[1] )
    PSNR.append(img_metrics[0])
    MAE.append(img_metrics[1])
    # ckpt_save_path = ckpt_manager.save()
    # print('Saving checkpoint for epoch', epoch, 'at', ckpt_save_path)
# Out:
# 2022-04-11 07:47:12.407149: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# Epoch 0 PSNR metrics: 53.24327816690457 MAE metrics: 0.38781723
# Epoch 1 PSNR metrics: 52.11754526877972 MAE metrics: 0.44268963
# Epoch 2 PSNR metrics: 53.64485401382608 MAE metrics: 0.35548016
# Epoch 3 PSNR metrics: 53.478324186063105 MAE metrics: 0.3575872
# Epoch 4 PSNR metrics: 53.101171046299314 MAE metrics: 0.37719524
# Epoch 5 PSNR metrics: 53.53842426174782 MAE metrics: 0.34626514
# Epoch 6 PSNR metrics: 53.48522705312335 MAE metrics: 0.35559428
# Epoch 7 PSNR metrics: 53.813257334594546 MAE metrics: 0.33378482
# Epoch 8 PSNR metrics: 53.7260387576659 MAE metrics: 0.34535423
# Epoch 9 PSNR metrics: 54.05892304671167 MAE metrics: 0.31667578
# Epoch 10 PSNR metrics: 53.699850759639894 MAE metrics: 0.3453663
# Epoch 11 PSNR metrics: 53.16820828955702 MAE metrics: 0.37535852
# Epoch 12 PSNR metrics: 53.3248839768531 MAE metrics: 0.35892034
# Epoch 13 PSNR metrics: 53.213992981990934 MAE metrics: 0.37064394
# Epoch 14 PSNR metrics: 52.947344597046836 MAE metrics: 0.38348162
# Epoch 15 PSNR metrics: 53.490153092931365 MAE metrics: 0.3430039
# Epoch 16 PSNR metrics: 53.89371593683143 MAE metrics: 0.32219568
# Epoch 17 PSNR metrics: 53.90802502576513 MAE metrics: 0.32270163
# Epoch 18 PSNR metrics: 53.62138750561938 MAE metrics: 0.33578634
# Epoch 19 PSNR metrics: 54.18228760892576 MAE metrics: 0.31266153
# Epoch 20 PSNR metrics: 53.50859864510171 MAE metrics: 0.34679124
# Epoch 21 PSNR metrics: 53.83245388747328 MAE metrics: 0.32732362
# Epoch 22 PSNR metrics: 54.4358314489066 MAE metrics: 0.2974663
# Epoch 23 PSNR metrics: 53.931039737793185 MAE metrics: 0.32168046
# Epoch 24 PSNR metrics: 54.053396239048 MAE metrics: 0.31108087
# Epoch 25 PSNR metrics: 53.931013656291185 MAE metrics: 0.32891855
# Epoch 26 PSNR metrics: 54.13945754303532 MAE metrics: 0.31242448
# Epoch 27 PSNR metrics: 54.56211181795932 MAE metrics: 0.28982422
# Epoch 28 PSNR metrics: 53.753912753380355 MAE metrics: 0.33049417
# Epoch 29 PSNR metrics: 54.15521457271766 MAE metrics: 0.3084408
# Epoch 30 PSNR metrics: 54.06869674394271 MAE metrics: 0.31518206
# Epoch 31 PSNR metrics: 54.192684789714896 MAE metrics: 0.3072576
# Epoch 32 PSNR metrics: 54.01960022155037 MAE metrics: 0.31800586
# Epoch 33 PSNR metrics: 54.488240236171855 MAE metrics: 0.29095206
# Epoch 34 PSNR metrics: 54.303940542495056 MAE metrics: 0.29954132
# Epoch 35 PSNR metrics: 54.37570078850434 MAE metrics: 0.29828194
# Epoch 36 PSNR metrics: 54.48563975146685 MAE metrics: 0.29441324
# Epoch 37 PSNR metrics: 53.99438461518371 MAE metrics: 0.31195414
# Epoch 38 PSNR metrics: 54.27345527392647 MAE metrics: 0.2978311
# Epoch 39 PSNR metrics: 54.63358803511806 MAE metrics: 0.2900278
# Epoch 40 PSNR metrics: 54.49935969133905 MAE metrics: 0.2963664
# Epoch 41 PSNR metrics: 54.02077412258965 MAE metrics: 0.31360283
# Epoch 42 PSNR metrics: 54.45765168045553 MAE metrics: 0.2974102
# Epoch 43 PSNR metrics: 54.486399684786576 MAE metrics: 0.28849363
# Epoch 44 PSNR metrics: 54.52426084606099 MAE metrics: 0.29513365
# Epoch 45 PSNR metrics: 55.04659801201045 MAE metrics: 0.2709532
# Epoch 46 PSNR metrics: 53.98677093249586 MAE metrics: 0.3133371
# Epoch 47 PSNR metrics: 54.386766361219 MAE metrics: 0.29323506
# Epoch 48 PSNR metrics: 54.92074081370269 MAE metrics: 0.27064967
# Epoch 49 PSNR metrics: 54.01464289791443 MAE metrics: 0.3107453
# Epoch 50 PSNR metrics: 54.02857553547439 MAE metrics: 0.30779058
# Epoch 51 PSNR metrics: 54.70515950435393 MAE metrics: 0.2783005
# Epoch 52 PSNR metrics: 54.39717860543737 MAE metrics: 0.29615632
# Epoch 53 PSNR metrics: 54.409797768747374 MAE metrics: 0.2913751
# Epoch 54 PSNR metrics: 54.597417164500186 MAE metrics: 0.2820723
# Epoch 55 PSNR metrics: 54.492889415554984 MAE metrics: 0.29116583
# Epoch 56 PSNR metrics: 54.60872256668678 MAE metrics: 0.28072882
# Epoch 57 PSNR metrics: 54.569140957943446 MAE metrics: 0.28498444
# Epoch 58 PSNR metrics: 54.330940984412806 MAE metrics: 0.2966288
# Epoch 59 PSNR metrics: 54.81492689296772 MAE metrics: 0.2734437
# Epoch 60 PSNR metrics: 55.06055734960756 MAE metrics: 0.2704082
# Epoch 61 PSNR metrics: 54.70292931705663 MAE metrics: 0.28104326
# Epoch 62 PSNR metrics: 54.84004492083811 MAE metrics: 0.27334505
# Epoch 63 PSNR metrics: 54.551181809616025 MAE metrics: 0.2863913
# Epoch 64 PSNR metrics: 54.86731653851059 MAE metrics: 0.27254975
# Epoch 65 PSNR metrics: 55.06897801032123 MAE metrics: 0.2649305
# Epoch 66 PSNR metrics: 55.0868280597781 MAE metrics: 0.26527977
# Epoch 67 PSNR metrics: 54.87037408311549 MAE metrics: 0.27194116
# Epoch 68 PSNR metrics: 54.76826704593088 MAE metrics: 0.27739775
# Epoch 69 PSNR metrics: 55.06605480442822 MAE metrics: 0.26347908
# Epoch 70 PSNR metrics: 54.873788385443476 MAE metrics: 0.27327895
# Epoch 71 PSNR metrics: 54.850720708320644 MAE metrics: 0.2727989
# Epoch 72 PSNR metrics: 55.061748539477186 MAE metrics: 0.26506492
# Epoch 73 PSNR metrics: 54.77277263521057 MAE metrics: 0.2738037
# Epoch 74 PSNR metrics: 54.93640585983754 MAE metrics: 0.26869947
# Epoch 75 PSNR metrics: 55.02187781404167 MAE metrics: 0.26639485
# Epoch 76 PSNR metrics: 55.21921712673891 MAE metrics: 0.2599461
# Epoch 77 PSNR metrics: 54.99498702054929 MAE metrics: 0.26991323
# Epoch 78 PSNR metrics: 55.67291641650493 MAE metrics: 0.24355066
# Epoch 79 PSNR metrics: 55.16630517848103 MAE metrics: 0.26277205
# Epoch 80 PSNR metrics: 55.287895117721924 MAE metrics: 0.25540903
# Epoch 81 PSNR metrics: 55.570979211583065 MAE metrics: 0.24862406
# Epoch 82 PSNR metrics: 55.32920031972108 MAE metrics: 0.25554448
# Epoch 83 PSNR metrics: 55.35449725531265 MAE metrics: 0.2530066
# Epoch 84 PSNR metrics: 55.58773487122422 MAE metrics: 0.24633355
# Epoch 85 PSNR metrics: 55.48710602356553 MAE metrics: 0.25253502
# Epoch 86 PSNR metrics: 55.58385695562072 MAE metrics: 0.24702865
# Epoch 87 PSNR metrics: 55.47072605185711 MAE metrics: 0.25137502
# Epoch 88 PSNR metrics: 55.57304324864265 MAE metrics: 0.24320623
# Epoch 89 PSNR metrics: 55.67603216526586 MAE metrics: 0.23919737
# Epoch 90 PSNR metrics: 55.513974447348616 MAE metrics: 0.25061825
# Epoch 91 PSNR metrics: 55.6036229976238 MAE metrics: 0.24231905
# Epoch 92 PSNR metrics: 55.887333594659495 MAE metrics: 0.23200458
# Epoch 93 PSNR metrics: 55.65502983890624 MAE metrics: 0.24064541
# Epoch 94 PSNR metrics: 55.76869655352654 MAE metrics: 0.23891069
# Epoch 95 PSNR metrics: 55.89871455483469 MAE metrics: 0.23342592
# Epoch 96 PSNR metrics: 55.63137904171947 MAE metrics: 0.24344322
# Epoch 97 PSNR metrics: 55.94038430293424 MAE metrics: 0.22990048
# Epoch 98 PSNR metrics: 55.88682325025164 MAE metrics: 0.23242377
# Epoch 99 PSNR metrics: 56.14606747188287 MAE metrics: 0.22529535
# Epoch 100 PSNR metrics: 56.34876628947546 MAE metrics: 0.21677476
# Epoch 101 PSNR metrics: 56.07253009532048 MAE metrics: 0.22644919
# Epoch 102 PSNR metrics: 56.046878005548976 MAE metrics: 0.22663474
# Epoch 103 PSNR metrics: 56.29043135955233 MAE metrics: 0.21849205
# Epoch 104 PSNR metrics: 56.186050653819926 MAE metrics: 0.22007473
# Epoch 105 PSNR metrics: 56.33051654853589 MAE metrics: 0.21671537
# Epoch 106 PSNR metrics: 56.16216687964612 MAE metrics: 0.22077361
# Epoch 107 PSNR metrics: 56.220214969924214 MAE metrics: 0.21849002
# Epoch 108 PSNR metrics: 56.19371058074339 MAE metrics: 0.21959554
# Epoch 109 PSNR metrics: 56.296764298990325 MAE metrics: 0.21647416
# Epoch 110 PSNR metrics: 56.247546461142726 MAE metrics: 0.21903285
# Epoch 111 PSNR metrics: 56.11298551649193 MAE metrics: 0.22146423
# Epoch 112 PSNR metrics: 56.31564785467095 MAE metrics: 0.21585004
# Epoch 113 PSNR metrics: 56.456172882726065 MAE metrics: 0.21088134
# Epoch 114 PSNR metrics: 56.390247314668926 MAE metrics: 0.21323434
# Epoch 115 PSNR metrics: 56.56535185306912 MAE metrics: 0.20706682
# Epoch 116 PSNR metrics: 56.45788472948184 MAE metrics: 0.21178477
# Epoch 117 PSNR metrics: 56.44788158801704 MAE metrics: 0.2121323
# Epoch 118 PSNR metrics: 56.56291464861917 MAE metrics: 0.2080957
# Epoch 119 PSNR metrics: 56.72164973723466 MAE metrics: 0.20298013
# Epoch 120 PSNR metrics: 56.832040388470986 MAE metrics: 0.20032214
# Epoch 121 PSNR metrics: 56.665368212509975 MAE metrics: 0.20510171
# Epoch 122 PSNR metrics: 56.72297062512225 MAE metrics: 0.20380431
# Epoch 123 PSNR metrics: 56.70060769687572 MAE metrics: 0.20458189
# Epoch 124 PSNR metrics: 56.687616796870415 MAE metrics: 0.20512234
# Epoch 125 PSNR metrics: 56.747488972836706 MAE metrics: 0.20175432
# Epoch 126 PSNR metrics: 56.75220764640986 MAE metrics: 0.20049977
# Epoch 127 PSNR metrics: 56.79140666881794 MAE metrics: 0.20008017
# Epoch 128 PSNR metrics: 56.803860179345534 MAE metrics: 0.1994157
# Epoch 129 PSNR metrics: 56.68167333662563 MAE metrics: 0.2022927
# Epoch 130 PSNR metrics: 56.66661942896937 MAE metrics: 0.20313707
# Epoch 131 PSNR metrics: 56.78195637728733 MAE metrics: 0.19910677
# Epoch 132 PSNR metrics: 56.71222615556016 MAE metrics: 0.20153707
# Epoch 133 PSNR metrics: 56.63371748071665 MAE metrics: 0.20184575
# Epoch 134 PSNR metrics: 56.74620389212549 MAE metrics: 0.19972292
# Epoch 135 PSNR metrics: 56.57086429193188 MAE metrics: 0.20483625
# Epoch 136 PSNR metrics: 56.61855630959273 MAE metrics: 0.20217057
# Epoch 137 PSNR metrics: 56.602008102151146 MAE metrics: 0.20183472
# Epoch 138 PSNR metrics: 56.58310905479765 MAE metrics: 0.20147358
# Epoch 139 PSNR metrics: 56.48799413036532 MAE metrics: 0.20517918
# Epoch 140 PSNR metrics: 56.65535070344652 MAE metrics: 0.20080425
# Epoch 141 PSNR metrics: 56.6678608404047 MAE metrics: 0.19856696
# Epoch 142 PSNR metrics: 56.586215098885404 MAE metrics: 0.20164192
# Epoch 143 PSNR metrics: 56.637411898991076 MAE metrics: 0.19903125
# Epoch 144 PSNR metrics: 56.6033154003783 MAE metrics: 0.20078453
# Epoch 145 PSNR metrics: 56.64178872440555 MAE metrics: 0.20029107
# Epoch 146 PSNR metrics: 56.60217285831891 MAE metrics: 0.19870053
# Epoch 147 PSNR metrics: 56.50589836476436 MAE metrics: 0.20147473
# Epoch 148 PSNR metrics: 56.59983636272213 MAE metrics: 0.20025668
# Epoch 149 PSNR metrics: 56.64360060858496 MAE metrics: 0.19795997
# Epoch 150 PSNR metrics: 56.55388609058032 MAE metrics: 0.20026244
# Epoch 151 PSNR metrics: 56.58532956835474 MAE metrics: 0.19974777
# Epoch 152 PSNR metrics: 56.80395458108384 MAE metrics: 0.1959715
# Epoch 153 PSNR metrics: 56.729472832259695 MAE metrics: 0.19661607
# Epoch 154 PSNR metrics: 56.698038976772516 MAE metrics: 0.19795127
# Epoch 155 PSNR metrics: 56.70354876600682 MAE metrics: 0.19580355
# Epoch 156 PSNR metrics: 56.65239650020341 MAE metrics: 0.19741963
# Epoch 157 PSNR metrics: 56.72458824225424 MAE metrics: 0.196296
# Epoch 158 PSNR metrics: 56.794089262840686 MAE metrics: 0.19390492
# Epoch 159 PSNR metrics: 56.73928435991789 MAE metrics: 0.19564506
# Epoch 160 PSNR metrics: 56.68556978459982 MAE metrics: 0.19788292
# Epoch 161 PSNR metrics: 56.61738189064745 MAE metrics: 0.19921505
# Epoch 162 PSNR metrics: 56.63426857744583 MAE metrics: 0.19852105
# Epoch 163 PSNR metrics: 56.752872939156745 MAE metrics: 0.19767387
# Epoch 164 PSNR metrics: 56.74574190184326 MAE metrics: 0.19502828
# Epoch 165 PSNR metrics: 56.73548493043949 MAE metrics: 0.19573921
# Epoch 166 PSNR metrics: 56.821026359691885 MAE metrics: 0.19208239
# Epoch 167 PSNR metrics: 56.853394933367966 MAE metrics: 0.1920063
# Epoch 168 PSNR metrics: 56.85950439158926 MAE metrics: 0.19087271
# Epoch 169 PSNR metrics: 56.85689644508691 MAE metrics: 0.19135843
# Epoch 170 PSNR metrics: 56.86684565311691 MAE metrics: 0.18988095
# Epoch 171 PSNR metrics: 56.90309777364713 MAE metrics: 0.18838355
# Epoch 172 PSNR metrics: 56.88510633382477 MAE metrics: 0.18958528
# Epoch 173 PSNR metrics: 56.95793809752621 MAE metrics: 0.19150351
# Epoch 174 PSNR metrics: 56.89231099859381 MAE metrics: 0.19061412
# Epoch 175 PSNR metrics: 56.88525595494227 MAE metrics: 0.19036508
# Epoch 176 PSNR metrics: 56.917640219796944 MAE metrics: 0.18977919
# Epoch 177 PSNR metrics: 56.7486558034838 MAE metrics: 0.19547242
# Epoch 178 PSNR metrics: 56.84701861205628 MAE metrics: 0.19091518
# Epoch 179 PSNR metrics: 56.8163915802739 MAE metrics: 0.1932422
# Epoch 180 PSNR metrics: 56.70627738101019 MAE metrics: 0.19516306
# Epoch 181 PSNR metrics: 56.81945616170127 MAE metrics: 0.19228932
# Epoch 182 PSNR metrics: 56.83107018965021 MAE metrics: 0.1909435
# Epoch 183 PSNR metrics: 56.73457876077218 MAE metrics: 0.19383954
# Epoch 184 PSNR metrics: 56.80765025720653 MAE metrics: 0.19140115
# Epoch 185 PSNR metrics: 56.824666654585194 MAE metrics: 0.19198923
# Epoch 186 PSNR metrics: 56.77789717007262 MAE metrics: 0.19274443
# Epoch 187 PSNR metrics: 56.78803592193446 MAE metrics: 0.19275242
# Epoch 188 PSNR metrics: 56.80799718639968 MAE metrics: 0.1908004
# Epoch 189 PSNR metrics: 56.822841337124 MAE metrics: 0.19144166
# Epoch 190 PSNR metrics: 56.855339761902 MAE metrics: 0.19076729
# Epoch 191 PSNR metrics: 56.83668566228796 MAE metrics: 0.18984057
# Epoch 192 PSNR metrics: 56.93866887623613 MAE metrics: 0.18860266
# Epoch 193 PSNR metrics: 56.83482455556658 MAE metrics: 0.19239257
# Epoch 194 PSNR metrics: 56.9363747306594 MAE metrics: 0.18791278
# Epoch 195 PSNR metrics: 56.90154443692995 MAE metrics: 0.19039287
# Epoch 196 PSNR metrics: 56.89742651693466 MAE metrics: 0.18953545
# Epoch 197 PSNR metrics: 56.90702822090893 MAE metrics: 0.18952915
# Epoch 198 PSNR metrics: 56.897616511343884 MAE metrics: 0.18918502
# Epoch 199 PSNR metrics: 56.918828222038925 MAE metrics: 0.18907784
# Epoch 200 PSNR metrics: 57.00567886279064 MAE metrics: 0.18690152
# Epoch 201 PSNR metrics: 56.927931843465586 MAE metrics: 0.18910974
# Epoch 202 PSNR metrics: 56.869325993255785 MAE metrics: 0.19086592
# Epoch 203 PSNR metrics: 56.95571867512505 MAE metrics: 0.18778253
# Epoch 204 PSNR metrics: 56.864281157125866 MAE metrics: 0.19055353
# Epoch 205 PSNR metrics: 56.99704945536716 MAE metrics: 0.18786089
# Epoch 206 PSNR metrics: 56.92601210494921 MAE metrics: 0.18940975
# Epoch 207 PSNR metrics: 56.93012729065612 MAE metrics: 0.18877743
# Epoch 208 PSNR metrics: 56.99242522628364 MAE metrics: 0.1876163
# Epoch 209 PSNR metrics: 56.95201623660723 MAE metrics: 0.18974933
# Epoch 210 PSNR metrics: 56.94964501808063 MAE metrics: 0.18890779
# Epoch 211 PSNR metrics: 56.867584865005256 MAE metrics: 0.19145234
# Epoch 212 PSNR metrics: 56.876026021 MAE metrics: 0.19104819
# Epoch 213 PSNR metrics: 57.00044029657561 MAE metrics: 0.188067
# Epoch 214 PSNR metrics: 56.88110199830991 MAE metrics: 0.19019464
# Epoch 215 PSNR metrics: 56.844164060558455 MAE metrics: 0.19470617
# Epoch 216 PSNR metrics: 56.90329679696169 MAE metrics: 0.19044986
# Epoch 217 PSNR metrics: 56.98246067813762 MAE metrics: 0.19002454
# Epoch 218 PSNR metrics: 56.92239026015744 MAE metrics: 0.19438377
# Epoch 219 PSNR metrics: 56.93236166194173 MAE metrics: 0.19104196
# Epoch 220 PSNR metrics: 56.92563649657809 MAE metrics: 0.1913778
# Epoch 221 PSNR metrics: 56.911554054494424 MAE metrics: 0.19191998
# Epoch 222 PSNR metrics: 56.90891516202009 MAE metrics: 0.19277608
# Epoch 223 PSNR metrics: 56.93752902706248 MAE metrics: 0.19165313
# Epoch 224 PSNR metrics: 56.881085011905554 MAE metrics: 0.19483465
# Epoch 225 PSNR metrics: 56.931093855145846 MAE metrics: 0.19173768
# Epoch 226 PSNR metrics: 56.78165516105963 MAE metrics: 0.19907925
# Epoch 227 PSNR metrics: 56.84661462478129 MAE metrics: 0.19491248
# Epoch 228 PSNR metrics: 56.94003285942526 MAE metrics: 0.19349469
# Epoch 229 PSNR metrics: 56.95904131658459 MAE metrics: 0.19217446
# Epoch 230 PSNR metrics: 56.90692129925846 MAE metrics: 0.19266187
# Epoch 231 PSNR metrics: 56.91375101565957 MAE metrics: 0.19299342
# Epoch 232 PSNR metrics: 56.88578890060636 MAE metrics: 0.19309187
# Epoch 233 PSNR metrics: 56.91128085643099 MAE metrics: 0.19246452
# Epoch 234 PSNR metrics: 56.82796911857903 MAE metrics: 0.19423246
# Epoch 235 PSNR metrics: 56.83777483965268 MAE metrics: 0.19194517
# Epoch 236 PSNR metrics: 56.887062988366054 MAE metrics: 0.19078547
# Epoch 237 PSNR metrics: 56.85804235827244 MAE metrics: 0.1911919
# Epoch 238 PSNR metrics: 56.920166398616885 MAE metrics: 0.18931653
# Epoch 239 PSNR metrics: 56.84169515961278 MAE metrics: 0.19099176
# Epoch 240 PSNR metrics: 56.880390082265755 MAE metrics: 0.19198011
# Epoch 241 PSNR metrics: 56.90293680557896 MAE metrics: 0.19014291
# Epoch 242 PSNR metrics: 56.8290187074448 MAE metrics: 0.19159813
# Epoch 243 PSNR metrics: 56.9528396599872 MAE metrics: 0.18893895
# Epoch 244 PSNR metrics: 56.861787267778865 MAE metrics: 0.19037783
# Epoch 245 PSNR metrics: 56.90731531123977 MAE metrics: 0.19003981
# Epoch 246 PSNR metrics: 56.92286162993036 MAE metrics: 0.18992111
# Epoch 247 PSNR metrics: 56.8604664732576 MAE metrics: 0.1913806
# Epoch 248 PSNR metrics: 56.992294273182786 MAE metrics: 0.18765453
# Epoch 249 PSNR metrics: 56.921353132801116 MAE metrics: 0.19006392
# Epoch 250 PSNR metrics: 56.95212180763236 MAE metrics: 0.18907097
# Epoch 251 PSNR metrics: 56.9677078441987 MAE metrics: 0.18851294
# Epoch 252 PSNR metrics: 56.96254254533721 MAE metrics: 0.18827978
# Epoch 253 PSNR metrics: 56.988408804776554 MAE metrics: 0.18737169
# Epoch 254 PSNR metrics: 56.96653362055807 MAE metrics: 0.18820149
# Epoch 255 PSNR metrics: 56.973577284300994 MAE metrics: 0.18761335
# Epoch 256 PSNR metrics: 56.945351713015725 MAE metrics: 0.1888476
# Epoch 257 PSNR metrics: 56.99407467715183 MAE metrics: 0.18667309
# Epoch 258 PSNR metrics: 56.97229045145826 MAE metrics: 0.18679483
# Epoch 259 PSNR metrics: 57.00260583600097 MAE metrics: 0.18517332
# Epoch 260 PSNR metrics: 56.95208924807055 MAE metrics: 0.1872703
# Epoch 261 PSNR metrics: 56.97140238246008 MAE metrics: 0.18707621
# Epoch 262 PSNR metrics: 56.864714834041564 MAE metrics: 0.19055703
# Epoch 263 PSNR metrics: 56.96437065263523 MAE metrics: 0.18728435
# Epoch 264 PSNR metrics: 56.964124782815034 MAE metrics: 0.18729964
# Epoch 265 PSNR metrics: 56.884883854811065 MAE metrics: 0.18983051
# Epoch 266 PSNR metrics: 56.898781992248445 MAE metrics: 0.18949923
# Epoch 267 PSNR metrics: 56.83687397867449 MAE metrics: 0.19050923
# Epoch 268 PSNR metrics: 56.94215174407397 MAE metrics: 0.18914966
# Epoch 269 PSNR metrics: 56.79724382236681 MAE metrics: 0.1920757
# Epoch 270 PSNR metrics: 56.88035562984857 MAE metrics: 0.19041684
# Epoch 271 PSNR metrics: 56.87758189410535 MAE metrics: 0.18922968
# Epoch 272 PSNR metrics: 56.8861494168889 MAE metrics: 0.1896041
# Epoch 273 PSNR metrics: 56.83423541134296 MAE metrics: 0.1899464
# Epoch 274 PSNR metrics: 56.9420892354652 MAE metrics: 0.1886671
# Epoch 275 PSNR metrics: 56.86141330786378 MAE metrics: 0.19005696
# Epoch 276 PSNR metrics: 56.90679924579743 MAE metrics: 0.18864393
# Epoch 277 PSNR metrics: 56.9247667397643 MAE metrics: 0.18775515
# Epoch 278 PSNR metrics: 57.028054826471916 MAE metrics: 0.1857584
# Epoch 279 PSNR metrics: 57.02050283488282 MAE metrics: 0.18825284
# Epoch 280 PSNR metrics: 57.07700394933096 MAE metrics: 0.18777238
# Epoch 281 PSNR metrics: 57.092090118687736 MAE metrics: 0.18621364
# Epoch 282 PSNR metrics: 57.1016826259503 MAE metrics: 0.18454129
# Epoch 283 PSNR metrics: 57.12883649337798 MAE metrics: 0.1856465
# Epoch 284 PSNR metrics: 57.16645589422421 MAE metrics: 0.18218102
# Epoch 285 PSNR metrics: 57.12335240137885 MAE metrics: 0.18432388
# Epoch 286 PSNR metrics: 57.26666581881561 MAE metrics: 0.18079528
# Epoch 287 PSNR metrics: 57.21610983509768 MAE metrics: 0.18273605
# Epoch 288 PSNR metrics: 57.28569334110789 MAE metrics: 0.18149751
# Epoch 289 PSNR metrics: 57.282407478120625 MAE metrics: 0.18160225
# Epoch 290 PSNR metrics: 57.297076610845835 MAE metrics: 0.18063626
# Epoch 291 PSNR metrics: 57.27560296680103 MAE metrics: 0.18126287
# Epoch 292 PSNR metrics: 57.28025721104927 MAE metrics: 0.18275353
# Epoch 293 PSNR metrics: 57.38491628434714 MAE metrics: 0.1790714
# Epoch 294 PSNR metrics: 57.2445439721708 MAE metrics: 0.18191728
# Epoch 295 PSNR metrics: 57.34445284243249 MAE metrics: 0.18066151
# Epoch 296 PSNR metrics: 57.396010236462146 MAE metrics: 0.17986056
# Epoch 297 PSNR metrics: 57.39850808541895 MAE metrics: 0.1800135
# Epoch 298 PSNR metrics: 57.37158639726316 MAE metrics: 0.17943557
# Epoch 299 PSNR metrics: 57.3793556948345 MAE metrics: 0.18070495

# %%
# print(PSNR)

# %%
# print(MAE)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.1, 0.1, 0.9, 0.9])
x_epoch = np.arange(EPOCHS)
# ax.plot(x_epoch, PSNR, 'r',label="PSNR")
ax.plot(x_epoch, MAE, 'b',label="MAE")
ax.set_xlabel("epoch")
ax.set_ylabel("metrics")
ax.legend()
plt.show()

# %%
tr1_test_data = load_images('/kaggle/input/d/jaquelinenoonan/mritestt1/') #write your code to create the dataset from image directory
tr1_test_data = tf.image.rgb_to_grayscale(tr1_test_data) #convert to grayscale
tr1_test= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr1_test_data))
tr1_test
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
tr2_test_data = load_images('/kaggle/input/d/jaquelinenoonan/mritestt2/') #write your code to create the dataset from image directory
tr2_test_data = tf.image.rgb_to_grayscale(tr2_test_data) #convert to grayscale
tr2_test= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr2_test_data))
tr2_test
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
tr1_test = tr1_test.map(preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)
tr2_test = tr2_test.map(preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)

# %%
# # Run the trained model on the train dataset
# iter_train = iter(tr2)
# for inp in tr1.take(5):  
#     sample_tr2 = iter_train.next()
#     generate_images(generator_g, inp, sample_tr2)

# %%
iter_test = iter(tr2_test)
j = 0
result = ['1', '2', '3', '4','5']
for inp in tr1_test.take(5):  
    sample_tr2_test = iter_test.next()
    prediction = generator_g(inp)
    plt.figure(figsize=(10, 10))
    display_list = [inp[0], prediction[0], sample_tr2_test[0]]
    title = ['Input Image', 'Predicted Image', 'Expected Image']
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off') 
    plt.savefig(result[j], dpi=300, bbox_inches = 'tight',pad_inches = 0)
    j = j+1
    img_metrics = metrics(generator_g, inp, sample_tr2_test)
    print('PSNR metrics:', img_metrics[0], 'MAE metrics:', img_metrics[1] )
# plt.savefig('test_result', dpi=300)
plt.show()
# fig=plt.gcf()
# Out:
# PSNR metrics: 58.448217354121574 MAE metrics: 0.15004124
# PSNR metrics: 57.59233356887005 MAE metrics: 0.16925555
# PSNR metrics: 55.873291683199255 MAE metrics: 0.23362777
# PSNR metrics: 57.09710942670594 MAE metrics: 0.17249663
# PSNR metrics: 59.7311843897208 MAE metrics: 0.14539851

# %%
# Run the trained model on the test dataset
iter_test = iter(tr1_test)
j = 0
result = ['1', '2', '3', '4','5']
for inp in tr2_test.take(5):  
    sample_tr1_test = iter_test.next()
    prediction = generator_f(inp)
    plt.figure(figsize=(10, 10))
    display_list = [inp[0], prediction[0], sample_tr1_test[0]]
    title = ['Input Image', 'Predicted Image', 'Expected Image']
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off') 
    plt.savefig(result[j], dpi=300, bbox_inches = 'tight',pad_inches = 0)
    j = j+1
    img_metrics = metrics(generator_f, inp, sample_tr1_test)
    print('PSNR metrics:', img_metrics[0], 'MAE metrics:', img_metrics[1] )
# plt.savefig('test_result', dpi=300)
plt.show()
# fig=plt.gcf()
# Out:
# PSNR metrics: 60.51784886772335 MAE metrics: 0.1302575
# PSNR metrics: 61.60414151507963 MAE metrics: 0.11370498
# PSNR metrics: 59.43648852320383 MAE metrics: 0.14395626
# PSNR metrics: 60.574755466304 MAE metrics: 0.12753247
# PSNR metrics: 59.5176328564432 MAE metrics: 0.15175925

# %%
generator_g.save_weights('cycle_geng.h5')

# %%
generator_f.save_weights('cycle_genf.h5')

# %%
# # Run the trained model on the test dataset
# iter_test = iter(tr2_test)
# for inp in tr1_test.take(5):  
#     sample_tr2_test = iter_test.next()
#     generate_images(generator_g, inp, sample_tr2_test)
