# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 90.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 100.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 125.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 95.png
# /kaggle/input/d/jaquelinenoonan/mritestt2/Image 75.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 71.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 88.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 93.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 111.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 73.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 120.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 97.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 112.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 92.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 99.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 77.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 74.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 114.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 122.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 123.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 84.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 113.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 78.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 86.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 121.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 91.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 118.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 79.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 115.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 70.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 124.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 96.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 85.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 116.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 76.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 117.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 72.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 89.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 87.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 94.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 83.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 119.png
# /kaggle/input/d/jaquelinenoonan/mritraint2/Image 98.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 90.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 100.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 125.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 95.png
# /kaggle/input/d/jaquelinenoonan/mritestt1/Image 75.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 71.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 88.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 93.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 111.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 73.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 120.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 97.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 112.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 92.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 99.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 77.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 74.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 114.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 122.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 123.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 84.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 113.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 78.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 86.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 121.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 91.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 118.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 79.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 115.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 70.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 124.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 96.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 85.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 116.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 76.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 117.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 72.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 89.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 87.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 94.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 83.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 119.png
# /kaggle/input/d/jaquelinenoonan/mritraint1/Image 98.png

# %%
#Import all the required libraries
import os
from os import listdir
import numpy as np
from numpy import asarray
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import tensorflow as tf
strategy = tf.distribute.MirroredStrategy()
# Out:
# 2022-04-12 04:20:02.640422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:02.743922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:02.744726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:02.747452: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-12 04:20:02.748195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:02.748903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:02.749522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:04.622798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:04.623727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:04.624423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-12 04:20:04.625040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 1

# %%
# load and resize images
def load_images(path, size=(256,256)):
    data_list = list()
    
    for filename in listdir(path):     
        pixels = load_img(path + filename, target_size=size)
        # convert to numpy array
        pixels = img_to_array(pixels)
        # store the data
        data_list.append(pixels)
    return asarray(data_list)

# %%
import tensorflow as tf
tr1_data = load_images('/kaggle/input/d/jaquelinenoonan/mritraint1/') #write your code to create the dataset from image directory
tr1_data = tf.image.rgb_to_grayscale(tr1_data) #convert to grayscale
tr1= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr1_data))
tr1
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
tr2_data = load_images('/kaggle/input/d/jaquelinenoonan/mritraint2/') #write your code to create the dataset from image directory
tr2_data = tf.image.rgb_to_grayscale(tr2_data) #convert to grayscale
tr2= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr2_data))
tr2
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
# image preprocess
BUFFER_SIZE = 1000
BATCH_SIZE = 1

# normalizing the images to [-1, 1]
def normalize(image):
    image =  tf.cast(image, tf.float32)
    image= (image / 127.5) - 1 
    return image

def preprocess_image_train(image):
#     image = tf.image.random_flip_left_right(image)
    image = normalize(image)   
    return image


def preprocess_image_test(image):
    image = normalize(image)   
    return image

# %%
# process both classes of MRI images
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

tr1 = tr1.map(preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)
tr2 = tr2.map(preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)

sample_tr1 = next(iter(tr1))
sample_tr2 = next(iter(tr2))

tr1 = tr1.shuffle(BUFFER_SIZE)
tr2 = tr2.shuffle(BUFFER_SIZE)
# Out:
# 2022-04-12 04:20:06.801962: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-04-12 04:20:06.839198: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2022-04-12 04:20:06.852359: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
# plt.title('tr1')
# plt.imshow(sample_tr1[0].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')

# %%
# plt.title('tr2')
# plt.imshow(sample_tr2[0].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')

# %%
class InstanceNormalization(tf.keras.layers.Layer):
    def __init__(self, epsilon=1e-5):
        super(InstanceNormalization, self).__init__()
        self.epsilon = epsilon
    def build(self, input_shape):
        self.scale = self.add_weight(
            name='scale',
            shape=input_shape[-1:],
            initializer=tf.random_normal_initializer(1., 0.02),
            trainable=True)
        self.offset = self.add_weight(
            name='offset',
            shape=input_shape[-1:],
            initializer='zeros',
            trainable=True)
    def call(self, x):
        mean, variance = tf.nn.moments(x, axes=[1, 2], keepdims=True)
        inv = tf.math.rsqrt(variance + self.epsilon)
        normalized = (x - mean) * inv
        return self.scale * normalized + self.offset

def downsample(filters, size, apply_norm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    result = tf.keras.Sequential()
    result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                      kernel_initializer=initializer, use_bias=False))
    if apply_norm:
        result.add(InstanceNormalization())
    result.add(tf.keras.layers.LeakyReLU())
    return result

def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    result = tf.keras.Sequential()
    result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2, padding='same',
                                               kernel_initializer=initializer, use_bias=False))
    result.add(InstanceNormalization())
    if apply_dropout:
        result.add(tf.keras.layers.Dropout(0.5))
    result.add(tf.keras.layers.ReLU())
    return result

# %%
import keras

# %%
def unet_generator():
   
    down_stack = [
      downsample(64, 4, apply_norm=False), 
      downsample(128, 4), 
      downsample(256, 4),  
      downsample(512, 4),  
#       downsample(512, 4), 
#       downsample(512, 4),  
#       downsample(512, 4),  
      downsample(512, 4),  
    ]
                  #create a stack of downsample models
    up_stack = [
      upsample(512, 4, apply_dropout=True),  
#       upsample(512, 4, apply_dropout=True),  
#       upsample(512, 4, apply_dropout=True),  
#       upsample(512, 4),  
      upsample(256, 4),  
      upsample(128, 4),  
      upsample(64, 4),  
               ] #create a stack of upsample models
        
    initializer = tf.random_normal_initializer(0., 0.02)
    last = tf.keras.layers.Conv2DTranspose(1, 4, strides=2, padding='same', kernel_initializer=initializer,
                                           activation='tanh') 
    concat = tf.keras.layers.Concatenate()
    inputs = tf.keras.layers.Input(shape=[None, None, 1])
    x = inputs
    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = tf.keras.layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %%
with strategy.scope():
    generator_g = unet_generator() #initialise the generator
    generator_f = unet_generator() #initialise the generator

# %%
def discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    inp = tf.keras.layers.Input(shape=[None, None, 1], name='input_image')
    x = inp
    down1 = downsample(64, 4,  False)(x)  #write your code to downsample X
    down2 = downsample(128, 4)(down1)     #write your code to downsample down1
    down3 = downsample(256, 4)(down2)     #write your code to downsample down2
    zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = tf.keras.layers.Conv2D(512, 4, strides=1, kernel_initializer=initializer,
                                  use_bias=False)(zero_pad1) # (bs, 31, 31, 512)
    norm1 = InstanceNormalization()(conv)
    leaky_relu = tf.keras.layers.LeakyReLU()(norm1)
    zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)
    last = tf.keras.layers.Conv2D(1, 4, strides=1, kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)
  
    return tf.keras.Model(inputs=inp, outputs=last) #create the model using input & output layer

# %%
with strategy.scope():
    discriminator_x = discriminator() #initialise the discriminator
    discriminator_y = discriminator() #initialise the discriminator

# %%
# to_tr2 = generator_g(sample_tr1)
# to_tr1 = generator_f(sample_tr2)
# plt.figure(figsize=(8, 8))
# contrast = 8

# imgs = [sample_tr1, to_tr2, sample_tr2, to_tr1]
# title = ['tr1', 'To tr2', 'tr2', 'To tr1']

# for i in range(len(imgs)):
#     plt.subplot(2, 2, i+1)
#     plt.title(title[i])
#     if i % 2 == 0:
#         plt.imshow(imgs[i][0].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
#     else:
#         plt.imshow(imgs[i][0].numpy()[:, :, 0] * 0.5 * contrast + 0.5, cmap='gray')
# plt.show()

# %%
LAMBDA = 10

# %%
# Using Binarycross entropy with logits true
loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
with strategy.scope():
    # calculating discriminator loss by summing the real and generated
    def discriminator_loss(real, generated):
        real_loss = loss_obj(tf.ones_like(real), real) #write your code here
        generated_loss = loss_obj(tf.zeros_like(generated), generated) #write your code here
        total_disc_loss = real_loss + generated_loss #write your code here
        return total_disc_loss * 0.5

with strategy.scope():
    def generator_loss(generated):
        return loss_obj(tf.ones_like(generated), generated)

with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image)) #write your code here
        return LAMBDA * loss1
    
with strategy.scope():
    def identity_loss(real_image, same_image):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %%
with strategy.scope():
# Optimizer with learning rate 0.0001 for generator and discriminator
    generator_g_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)
    generator_f_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)

    discriminator_x_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)
    discriminator_y_optimizer = tf.keras.optimizers.Adam(0.0002, beta_1=0.9)

# %%
EPOCHS = 250 #"Your Number of Epochs Here"

# %%
# checkpoint_path = './checkpoints'  
# ckpt = tf.train.Checkpoint(generator_g=generator_g,
#                            generator_f=generator_f,
#                            discriminator_x=discriminator_x,
#                            discriminator_y=discriminator_y,
#                            generator_g_optimizer=generator_g_optimizer,
#                            generator_f_optimizer=generator_f_optimizer,
#                            discriminator_x_optimizer=discriminator_x_optimizer,
#                            discriminator_y_optimizer=discriminator_y_optimizer)

# ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=EPOCHS)

# # if a checkpoint exists, restore the latest checkpoint.
# if ckpt_manager.latest_checkpoint:
#     ckpt.restore(ckpt_manager.latest_checkpoint)
#     print ('Latest checkpoint restored!!')

# %%
def generate_images(model, test_input, expected_output):
    prediction = model(test_input)
    plt.figure(figsize=(10, 10))
    display_list = [test_input[0], prediction[0], expected_output[0]]
    title = ['Input Image', 'Predicted Image', 'Expected Image']
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off')
    plt.show()

# %%
# define the metrics to evaluate the difference between generated image and target image
import numpy
import math

def psnr(img1, img2):
    mse = numpy.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

def mae(img1, img2):
    mae1 = numpy.mean( abs(img1 - img2) )
    return mae1

def metrics(model, test_input, expected_output):
    prediction = model(test_input)
    m_psnr = psnr(prediction[0], expected_output[0])
    m_mae = mae(prediction[0], expected_output[0])
    return (m_psnr, m_mae)

# %%
with strategy.scope():
    @tf.function
    def train_step(real_x, real_y):
    # persistent is set to True because the tape is used more than
    # once to calculate the gradients.
        with tf.GradientTape(persistent=True) as tape:
            # Generator G translates X -> Y
            # Generator F translates Y -> X.
            fake_y = generator_g(real_x, training=True)  #write your code to generate images using Generator_g on real_x
            cycled_x = generator_f(fake_y, training=True) #write your code to generate images susiing Generator_f on fake_y

            fake_x =  generator_f(real_y, training=True) #write your code to generate images using Generator_f on real_y
            cycled_y = generator_g(fake_x, training=True) #write your code to generate images using Generator_g on fake_x

            # same_x and same_y are used for identity loss.
            same_x = generator_f(real_x, training=True) #write your code to generate images using Generator_f on real_x
            same_y = generator_g(real_y, training=True) #write your code to generate images using Generator_g on real_y

            disc_real_x =  discriminator_x(real_x, training=True) #write your code to discriminate images using Discriminator_x on real_x
            disc_real_y = discriminator_y(real_y, training=True) #write your code to discriminate images using Discriminator_y on real_y

            disc_fake_x = discriminator_x(fake_x, training=True) #write your code to discriminate images using Discriminator_x on fake_x
            disc_fake_y = discriminator_y(fake_y, training=True) #write your code to discriminate images using Discriminator_y on fake_y

            # calculate the loss
            gen_g_loss = generator_loss(disc_fake_y) # calculate the generator_loss for disc_fake_
            gen_f_loss = generator_loss(disc_fake_x) # calculate the generator_loss for disc_fake_X 

#             style_g_loss = tf.norm(generator_g(real_x - fake_y, training=True), ord=2)
#             style_f_loss = tf.norm(generator_f(real_y - fake_x, training=True), ord=2)
            
            identity_g_loss = identity_loss(real_y, same_y)
            identity_f_loss = identity_loss(real_x, same_x)
        
            total_cycle_loss = calc_cycle_loss(real_x, cycled_x) + calc_cycle_loss(real_y, cycled_y)
     #calculate the total cycle loss

            # Total generator loss = adversarial loss + cycle loss
            total_gen_g_loss = gen_g_loss + total_cycle_loss + identity_g_loss
            total_gen_f_loss = gen_f_loss + total_cycle_loss + identity_f_loss
        

            disc_x_loss = discriminator_loss(disc_real_x, disc_fake_x) # calculate the discriminator_loss for disc_fake_x wrt disc_real_x
            disc_y_loss = discriminator_loss(disc_real_y, disc_fake_y) # calculate the discriminator_loss foor disc_fake_y wrt disc_real_y

        # Calculate the gradients for generator and discriminator
        generator_g_gradients = tape.gradient(total_gen_g_loss, 
                                            generator_g.trainable_variables) #write your code here
        generator_f_gradients = tape.gradient(total_gen_f_loss, 
                                            generator_f.trainable_variables) #write your code here

        discriminator_x_gradients = tape.gradient(disc_x_loss, 
                                                discriminator_x.trainable_variables) #write your code here
        discriminator_y_gradients = tape.gradient(disc_y_loss, 
                                                discriminator_y.trainable_variables)
     #write your code here

        # Apply the gradients to the optimizer

        generator_g_optimizer.apply_gradients(zip(generator_g_gradients, 
                                                generator_g.trainable_variables))

        generator_f_optimizer.apply_gradients(zip(generator_f_gradients, 
                                                generator_f.trainable_variables))

        discriminator_x_optimizer.apply_gradients(zip(discriminator_x_gradients,
                                                    discriminator_x.trainable_variables))

        discriminator_y_optimizer.apply_gradients(zip(discriminator_y_gradients,
                                                    discriminator_y.trainable_variables)) #write your code here

# %%
PSNR = []
MAE = []
for epoch in range(EPOCHS):
    for image_x, image_y in tf.data.Dataset.zip((tr1, tr2)):
        train_step(image_x, image_y)
#     generate_images(generator_g, sample_tr1, sample_tr2)
    img_metrics = metrics(generator_g, sample_tr1, sample_tr2)
    print('Epoch', epoch, 'PSNR metrics:', img_metrics[0], 'MAE metrics:', img_metrics[1] )
    PSNR.append(img_metrics[0])
    MAE.append(img_metrics[1])
    # ckpt_save_path = ckpt_manager.save()
    # print('Saving checkpoint for epoch', epoch, 'at', ckpt_save_path)
# Out:
# 2022-04-12 04:20:23.960731: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# Epoch 0 PSNR metrics: 52.357153829890976 MAE metrics: 0.43332344
# Epoch 1 PSNR metrics: 52.44034031287932 MAE metrics: 0.41968098
# Epoch 2 PSNR metrics: 53.13356110210874 MAE metrics: 0.3805732
# Epoch 3 PSNR metrics: 53.152020334272166 MAE metrics: 0.37261617
# Epoch 4 PSNR metrics: 53.38229647826527 MAE metrics: 0.3643251
# Epoch 5 PSNR metrics: 53.52147983124223 MAE metrics: 0.35016665
# Epoch 6 PSNR metrics: 53.48203162667616 MAE metrics: 0.34389925
# Epoch 7 PSNR metrics: 53.410813791284816 MAE metrics: 0.3466013
# Epoch 8 PSNR metrics: 53.373175929688614 MAE metrics: 0.35007137
# Epoch 9 PSNR metrics: 53.51466624643416 MAE metrics: 0.34574708
# Epoch 10 PSNR metrics: 53.57958932427067 MAE metrics: 0.3386621
# Epoch 11 PSNR metrics: 53.731562131832966 MAE metrics: 0.3329777
# Epoch 12 PSNR metrics: 53.40649495314851 MAE metrics: 0.34275043
# Epoch 13 PSNR metrics: 53.804057098261836 MAE metrics: 0.32390156
# Epoch 14 PSNR metrics: 53.436264519001504 MAE metrics: 0.34216562
# Epoch 15 PSNR metrics: 53.711104176241726 MAE metrics: 0.33410153
# Epoch 16 PSNR metrics: 53.84549719798025 MAE metrics: 0.3190465
# Epoch 17 PSNR metrics: 53.29723954311531 MAE metrics: 0.3481021
# Epoch 18 PSNR metrics: 53.60941738019286 MAE metrics: 0.33302626
# Epoch 19 PSNR metrics: 53.45596269511312 MAE metrics: 0.34330672
# Epoch 20 PSNR metrics: 53.37993738846588 MAE metrics: 0.344761
# Epoch 21 PSNR metrics: 53.87566142443787 MAE metrics: 0.31746677
# Epoch 22 PSNR metrics: 54.00454849112308 MAE metrics: 0.31200358
# Epoch 23 PSNR metrics: 54.13074035763712 MAE metrics: 0.30729422
# Epoch 24 PSNR metrics: 54.13083722796894 MAE metrics: 0.3122135
# Epoch 25 PSNR metrics: 53.70910056364178 MAE metrics: 0.3253196
# Epoch 26 PSNR metrics: 53.85903378082439 MAE metrics: 0.31764024
# Epoch 27 PSNR metrics: 54.07102684245902 MAE metrics: 0.30892986
# Epoch 28 PSNR metrics: 53.89304562193773 MAE metrics: 0.31464514
# Epoch 29 PSNR metrics: 54.41478833238126 MAE metrics: 0.2973282
# Epoch 30 PSNR metrics: 54.183839093141906 MAE metrics: 0.30346167
# Epoch 31 PSNR metrics: 53.64822873510498 MAE metrics: 0.33582318
# Epoch 32 PSNR metrics: 54.16820335063993 MAE metrics: 0.30428073
# Epoch 33 PSNR metrics: 53.69365927364881 MAE metrics: 0.33358458
# Epoch 34 PSNR metrics: 54.25842795535754 MAE metrics: 0.29627952
# Epoch 35 PSNR metrics: 54.10121032571881 MAE metrics: 0.3035958
# Epoch 36 PSNR metrics: 54.44142511920262 MAE metrics: 0.28992116
# Epoch 37 PSNR metrics: 54.41415687621734 MAE metrics: 0.29275194
# Epoch 38 PSNR metrics: 54.41866901765093 MAE metrics: 0.2937041
# Epoch 39 PSNR metrics: 54.2573787490684 MAE metrics: 0.29981375
# Epoch 40 PSNR metrics: 54.092590949009285 MAE metrics: 0.30451354
# Epoch 41 PSNR metrics: 54.29678888546186 MAE metrics: 0.297615
# Epoch 42 PSNR metrics: 54.16436141730729 MAE metrics: 0.30090636
# Epoch 43 PSNR metrics: 54.548661372431155 MAE metrics: 0.2858738
# Epoch 44 PSNR metrics: 54.850490217404015 MAE metrics: 0.27581337
# Epoch 45 PSNR metrics: 54.59577321012244 MAE metrics: 0.2837895
# Epoch 46 PSNR metrics: 54.56347352997885 MAE metrics: 0.28487295
# Epoch 47 PSNR metrics: 54.85809161366893 MAE metrics: 0.2718922
# Epoch 48 PSNR metrics: 55.02631600146217 MAE metrics: 0.2678082
# Epoch 49 PSNR metrics: 54.84686205383685 MAE metrics: 0.27102584
# Epoch 50 PSNR metrics: 54.6834736779305 MAE metrics: 0.27637336
# Epoch 51 PSNR metrics: 54.784566052600624 MAE metrics: 0.27429223
# Epoch 52 PSNR metrics: 54.84775566785509 MAE metrics: 0.27208623
# Epoch 53 PSNR metrics: 55.09186929783485 MAE metrics: 0.26278555
# Epoch 54 PSNR metrics: 55.165114389021824 MAE metrics: 0.2575228
# Epoch 55 PSNR metrics: 55.26331845224693 MAE metrics: 0.25299683
# Epoch 56 PSNR metrics: 55.024019439079304 MAE metrics: 0.26404685
# Epoch 57 PSNR metrics: 55.397086977864696 MAE metrics: 0.24696241
# Epoch 58 PSNR metrics: 55.239883731684 MAE metrics: 0.25449303
# Epoch 59 PSNR metrics: 55.40690704239427 MAE metrics: 0.24812907
# Epoch 60 PSNR metrics: 55.34717512677582 MAE metrics: 0.2512409
# Epoch 61 PSNR metrics: 55.65228860742428 MAE metrics: 0.23824914
# Epoch 62 PSNR metrics: 55.41605381260857 MAE metrics: 0.24780154
# Epoch 63 PSNR metrics: 55.402443762752014 MAE metrics: 0.24883415
# Epoch 64 PSNR metrics: 55.51061134735611 MAE metrics: 0.24287719
# Epoch 65 PSNR metrics: 55.82807000107123 MAE metrics: 0.23468406
# Epoch 66 PSNR metrics: 55.46436601643697 MAE metrics: 0.24474283
# Epoch 67 PSNR metrics: 55.79149907829568 MAE metrics: 0.2354396
# Epoch 68 PSNR metrics: 55.64336498391988 MAE metrics: 0.23810469
# Epoch 69 PSNR metrics: 55.88741466850464 MAE metrics: 0.22911498
# Epoch 70 PSNR metrics: 55.967047513639265 MAE metrics: 0.22742568
# Epoch 71 PSNR metrics: 56.16777216973045 MAE metrics: 0.22084984
# Epoch 72 PSNR metrics: 56.12186895629464 MAE metrics: 0.21991904
# Epoch 73 PSNR metrics: 56.20104332893071 MAE metrics: 0.21968235
# Epoch 74 PSNR metrics: 56.18971502094919 MAE metrics: 0.21959786
# Epoch 75 PSNR metrics: 56.15862101176787 MAE metrics: 0.2199009
# Epoch 76 PSNR metrics: 56.4489275693052 MAE metrics: 0.21021171
# Epoch 77 PSNR metrics: 56.394490790970906 MAE metrics: 0.21356766
# Epoch 78 PSNR metrics: 56.57159547406101 MAE metrics: 0.20745032
# Epoch 79 PSNR metrics: 56.44113467348981 MAE metrics: 0.21129021
# Epoch 80 PSNR metrics: 56.580372029376335 MAE metrics: 0.20734115
# Epoch 81 PSNR metrics: 56.49349041946395 MAE metrics: 0.21049134
# Epoch 82 PSNR metrics: 56.47717759370327 MAE metrics: 0.20882747
# Epoch 83 PSNR metrics: 56.36513560904539 MAE metrics: 0.2128352
# Epoch 84 PSNR metrics: 56.3324716967856 MAE metrics: 0.21326855
# Epoch 85 PSNR metrics: 56.522487202697036 MAE metrics: 0.20841724
# Epoch 86 PSNR metrics: 56.343352261622954 MAE metrics: 0.21217966
# Epoch 87 PSNR metrics: 56.28315347044463 MAE metrics: 0.2146866
# Epoch 88 PSNR metrics: 56.26004638290958 MAE metrics: 0.21502414
# Epoch 89 PSNR metrics: 56.39691774554204 MAE metrics: 0.21002474
# Epoch 90 PSNR metrics: 56.378545808478094 MAE metrics: 0.21027374
# Epoch 91 PSNR metrics: 56.349038069786346 MAE metrics: 0.21027054
# Epoch 92 PSNR metrics: 56.318703907081165 MAE metrics: 0.21241394
# Epoch 93 PSNR metrics: 56.31063666403243 MAE metrics: 0.2131755
# Epoch 94 PSNR metrics: 56.4732095665876 MAE metrics: 0.2082349
# Epoch 95 PSNR metrics: 56.44869076273654 MAE metrics: 0.20672497
# Epoch 96 PSNR metrics: 56.5303868479002 MAE metrics: 0.2059719
# Epoch 97 PSNR metrics: 56.563849305077206 MAE metrics: 0.2036311
# Epoch 98 PSNR metrics: 56.4824817646138 MAE metrics: 0.20463166
# Epoch 99 PSNR metrics: 56.75015304418107 MAE metrics: 0.19668646
# Epoch 100 PSNR metrics: 56.809060575333916 MAE metrics: 0.19753519
# Epoch 101 PSNR metrics: 56.687898562828536 MAE metrics: 0.20008287
# Epoch 102 PSNR metrics: 56.6740648967421 MAE metrics: 0.19920212
# Epoch 103 PSNR metrics: 56.904324253550556 MAE metrics: 0.19347811
# Epoch 104 PSNR metrics: 56.83240798825835 MAE metrics: 0.19437711
# Epoch 105 PSNR metrics: 56.71140743568931 MAE metrics: 0.19751091
# Epoch 106 PSNR metrics: 56.76337846366014 MAE metrics: 0.19600841
# Epoch 107 PSNR metrics: 56.92159267399654 MAE metrics: 0.19111162
# Epoch 108 PSNR metrics: 56.77262932187041 MAE metrics: 0.19568981
# Epoch 109 PSNR metrics: 56.84281157172343 MAE metrics: 0.19478676
# Epoch 110 PSNR metrics: 56.82597181258036 MAE metrics: 0.19448741
# Epoch 111 PSNR metrics: 56.827846387428984 MAE metrics: 0.19365695
# Epoch 112 PSNR metrics: 56.73941353883866 MAE metrics: 0.19687931
# Epoch 113 PSNR metrics: 56.80363610262738 MAE metrics: 0.19606231
# Epoch 114 PSNR metrics: 56.81321735328134 MAE metrics: 0.19653244
# Epoch 115 PSNR metrics: 56.9029090026078 MAE metrics: 0.19298577
# Epoch 116 PSNR metrics: 56.807274726854295 MAE metrics: 0.1961517
# Epoch 117 PSNR metrics: 56.875455011406416 MAE metrics: 0.19342266
# Epoch 118 PSNR metrics: 56.8062270400204 MAE metrics: 0.19613457
# Epoch 119 PSNR metrics: 56.74969910914463 MAE metrics: 0.1971941
# Epoch 120 PSNR metrics: 56.78926074063309 MAE metrics: 0.19594601
# Epoch 121 PSNR metrics: 56.72708699704656 MAE metrics: 0.19788462
# Epoch 122 PSNR metrics: 56.80732625895751 MAE metrics: 0.19685401
# Epoch 123 PSNR metrics: 56.779761535073646 MAE metrics: 0.1956238
# Epoch 124 PSNR metrics: 56.86278126868601 MAE metrics: 0.1960442
# Epoch 125 PSNR metrics: 56.755704871476816 MAE metrics: 0.1977698
# Epoch 126 PSNR metrics: 56.84272161319781 MAE metrics: 0.19583043
# Epoch 127 PSNR metrics: 56.924211343598955 MAE metrics: 0.19448385
# Epoch 128 PSNR metrics: 56.81959444649821 MAE metrics: 0.19554855
# Epoch 129 PSNR metrics: 56.91344198555317 MAE metrics: 0.19353908
# Epoch 130 PSNR metrics: 56.906897864727874 MAE metrics: 0.19394846
# Epoch 131 PSNR metrics: 56.97985928764277 MAE metrics: 0.19126874
# Epoch 132 PSNR metrics: 57.09991932479948 MAE metrics: 0.18751319
# Epoch 133 PSNR metrics: 56.93624889746844 MAE metrics: 0.19210222
# Epoch 134 PSNR metrics: 57.04133723988362 MAE metrics: 0.18885472
# Epoch 135 PSNR metrics: 57.088615788722514 MAE metrics: 0.1877223
# Epoch 136 PSNR metrics: 57.09916552017027 MAE metrics: 0.18798777
# Epoch 137 PSNR metrics: 57.06614825374609 MAE metrics: 0.18832035
# Epoch 138 PSNR metrics: 57.160902640580375 MAE metrics: 0.18662432
# Epoch 139 PSNR metrics: 57.16858942509301 MAE metrics: 0.18586834
# Epoch 140 PSNR metrics: 57.11203897327317 MAE metrics: 0.18681847
# Epoch 141 PSNR metrics: 57.05688751776883 MAE metrics: 0.18929641
# Epoch 142 PSNR metrics: 57.179609684858754 MAE metrics: 0.1839119
# Epoch 143 PSNR metrics: 57.10244759239795 MAE metrics: 0.18770213
# Epoch 144 PSNR metrics: 57.15793456430421 MAE metrics: 0.18603334
# Epoch 145 PSNR metrics: 57.165501056857536 MAE metrics: 0.1851311
# Epoch 146 PSNR metrics: 57.22172892865606 MAE metrics: 0.18274617
# Epoch 147 PSNR metrics: 57.177961526781516 MAE metrics: 0.18587106
# Epoch 148 PSNR metrics: 57.21719122689841 MAE metrics: 0.18403113
# Epoch 149 PSNR metrics: 57.4156562625019 MAE metrics: 0.17966232
# Epoch 150 PSNR metrics: 57.1940029141946 MAE metrics: 0.18356593
# Epoch 151 PSNR metrics: 57.29519774689845 MAE metrics: 0.18043472
# Epoch 152 PSNR metrics: 57.23239273093493 MAE metrics: 0.18349072
# Epoch 153 PSNR metrics: 57.2512029755304 MAE metrics: 0.18324713
# Epoch 154 PSNR metrics: 57.19188084617861 MAE metrics: 0.18417993
# Epoch 155 PSNR metrics: 57.338137901080245 MAE metrics: 0.17966405
# Epoch 156 PSNR metrics: 57.31931482267533 MAE metrics: 0.1792605
# Epoch 157 PSNR metrics: 57.405121473696916 MAE metrics: 0.17791502
# Epoch 158 PSNR metrics: 57.37768330095096 MAE metrics: 0.17898004
# Epoch 159 PSNR metrics: 57.331946271642245 MAE metrics: 0.18036674
# Epoch 160 PSNR metrics: 57.452156252843025 MAE metrics: 0.17769766
# Epoch 161 PSNR metrics: 57.38695133596883 MAE metrics: 0.17900431
# Epoch 162 PSNR metrics: 57.406584267918916 MAE metrics: 0.17970508
# Epoch 163 PSNR metrics: 57.339756566660036 MAE metrics: 0.18084534
# Epoch 164 PSNR metrics: 57.50271949813761 MAE metrics: 0.17703775
# Epoch 165 PSNR metrics: 57.43964904554357 MAE metrics: 0.17853248
# Epoch 166 PSNR metrics: 57.41066527998125 MAE metrics: 0.17995586
# Epoch 167 PSNR metrics: 57.45148293808204 MAE metrics: 0.17838572
# Epoch 168 PSNR metrics: 57.45527595049925 MAE metrics: 0.17732446
# Epoch 169 PSNR metrics: 57.38073632675971 MAE metrics: 0.17821878
# Epoch 170 PSNR metrics: 57.44977590408381 MAE metrics: 0.17723607
# Epoch 171 PSNR metrics: 57.64318775864499 MAE metrics: 0.1725758
# Epoch 172 PSNR metrics: 57.57729713686572 MAE metrics: 0.1745888
# Epoch 173 PSNR metrics: 57.56262457394507 MAE metrics: 0.17377988
# Epoch 174 PSNR metrics: 57.58690337722493 MAE metrics: 0.17342052
# Epoch 175 PSNR metrics: 57.67200019935788 MAE metrics: 0.17146528
# Epoch 176 PSNR metrics: 57.7068129251628 MAE metrics: 0.16951455
# Epoch 177 PSNR metrics: 57.61749330959223 MAE metrics: 0.1716429
# Epoch 178 PSNR metrics: 57.79288115124639 MAE metrics: 0.16784951
# Epoch 179 PSNR metrics: 57.745867362167395 MAE metrics: 0.16709974
# Epoch 180 PSNR metrics: 57.77592457348362 MAE metrics: 0.16743919
# Epoch 181 PSNR metrics: 57.74648927739957 MAE metrics: 0.16684124
# Epoch 182 PSNR metrics: 57.82488757425453 MAE metrics: 0.16712514
# Epoch 183 PSNR metrics: 57.83165818782206 MAE metrics: 0.16545501
# Epoch 184 PSNR metrics: 57.828475885964174 MAE metrics: 0.16567467
# Epoch 185 PSNR metrics: 57.87790740817336 MAE metrics: 0.16571504
# Epoch 186 PSNR metrics: 57.8799241878923 MAE metrics: 0.1652996
# Epoch 187 PSNR metrics: 57.895807453653454 MAE metrics: 0.16553
# Epoch 188 PSNR metrics: 57.88585873629967 MAE metrics: 0.16533655
# Epoch 189 PSNR metrics: 57.89205437401503 MAE metrics: 0.16385993
# Epoch 190 PSNR metrics: 57.93326448858667 MAE metrics: 0.16333234
# Epoch 191 PSNR metrics: 57.88323734204043 MAE metrics: 0.16396013
# Epoch 192 PSNR metrics: 57.94532961146595 MAE metrics: 0.16263813
# Epoch 193 PSNR metrics: 58.03538411527057 MAE metrics: 0.15924588
# Epoch 194 PSNR metrics: 57.92296842521455 MAE metrics: 0.16211852
# Epoch 195 PSNR metrics: 57.89640124535357 MAE metrics: 0.16240047
# Epoch 196 PSNR metrics: 58.00357815586702 MAE metrics: 0.15923385
# Epoch 197 PSNR metrics: 58.0560550462571 MAE metrics: 0.15893096
# Epoch 198 PSNR metrics: 58.05811461001673 MAE metrics: 0.15953591
# Epoch 199 PSNR metrics: 57.99858378027689 MAE metrics: 0.16187704
# Epoch 200 PSNR metrics: 58.09732901419398 MAE metrics: 0.15855426
# Epoch 201 PSNR metrics: 58.214990710783205 MAE metrics: 0.15904284
# Epoch 202 PSNR metrics: 58.26959018496104 MAE metrics: 0.15489613
# Epoch 203 PSNR metrics: 58.45202629689937 MAE metrics: 0.15068242
# Epoch 204 PSNR metrics: 58.72823291080611 MAE metrics: 0.14673312
# Epoch 205 PSNR metrics: 58.94996718766763 MAE metrics: 0.1417996
# Epoch 206 PSNR metrics: 58.93835812451126 MAE metrics: 0.14112556
# Epoch 207 PSNR metrics: 59.04920834895602 MAE metrics: 0.13978219
# Epoch 208 PSNR metrics: 59.14413894780648 MAE metrics: 0.13941118
# Epoch 209 PSNR metrics: 59.124819634366176 MAE metrics: 0.1375615
# Epoch 210 PSNR metrics: 59.36161297500969 MAE metrics: 0.13366689
# Epoch 211 PSNR metrics: 59.379840061495635 MAE metrics: 0.13253853
# Epoch 212 PSNR metrics: 59.52068693959571 MAE metrics: 0.13045095
# Epoch 213 PSNR metrics: 59.54594479418037 MAE metrics: 0.13070814
# Epoch 214 PSNR metrics: 59.617093994543204 MAE metrics: 0.12869889
# Epoch 215 PSNR metrics: 59.61066448035914 MAE metrics: 0.12899758
# Epoch 216 PSNR metrics: 59.700873653489225 MAE metrics: 0.12694202
# Epoch 217 PSNR metrics: 59.58928284235234 MAE metrics: 0.1306969
# Epoch 218 PSNR metrics: 59.75890350727039 MAE metrics: 0.12676585
# Epoch 219 PSNR metrics: 59.71219141926803 MAE metrics: 0.12738101
# Epoch 220 PSNR metrics: 59.83946732440373 MAE metrics: 0.12364328
# Epoch 221 PSNR metrics: 59.93156932661927 MAE metrics: 0.12421796
# Epoch 222 PSNR metrics: 60.04159910749018 MAE metrics: 0.12204577
# Epoch 223 PSNR metrics: 59.92093331921451 MAE metrics: 0.12352472
# Epoch 224 PSNR metrics: 60.05347560734983 MAE metrics: 0.12391342
# Epoch 225 PSNR metrics: 60.052792534279895 MAE metrics: 0.12204821
# Epoch 226 PSNR metrics: 60.11576021218297 MAE metrics: 0.12038509
# Epoch 227 PSNR metrics: 60.288438542384604 MAE metrics: 0.12046199
# Epoch 228 PSNR metrics: 60.35096386543187 MAE metrics: 0.11807638
# Epoch 229 PSNR metrics: 60.38936471860146 MAE metrics: 0.11963265
# Epoch 230 PSNR metrics: 60.62672992033075 MAE metrics: 0.115670815
# Epoch 231 PSNR metrics: 60.68092330677446 MAE metrics: 0.11332508
# Epoch 232 PSNR metrics: 60.75875062716618 MAE metrics: 0.114072084
# Epoch 233 PSNR metrics: 60.81205037912363 MAE metrics: 0.11150954
# Epoch 234 PSNR metrics: 61.06620011382095 MAE metrics: 0.10842203
# Epoch 235 PSNR metrics: 61.13939665647056 MAE metrics: 0.10726747
# Epoch 236 PSNR metrics: 61.1624899928023 MAE metrics: 0.10564353
# Epoch 237 PSNR metrics: 61.34586140403285 MAE metrics: 0.10265862
# Epoch 238 PSNR metrics: 61.40051827393006 MAE metrics: 0.10221484
# Epoch 239 PSNR metrics: 61.41387140079057 MAE metrics: 0.10359514
# Epoch 240 PSNR metrics: 61.59217859620802 MAE metrics: 0.100780845
# Epoch 241 PSNR metrics: 61.72901331776401 MAE metrics: 0.09882481
# Epoch 242 PSNR metrics: 61.721647375567144 MAE metrics: 0.10156935
# Epoch 243 PSNR metrics: 61.97467934712205 MAE metrics: 0.097322606
# Epoch 244 PSNR metrics: 61.91688276750103 MAE metrics: 0.097373955
# Epoch 245 PSNR metrics: 62.04014887155264 MAE metrics: 0.096225984
# Epoch 246 PSNR metrics: 62.1259564350306 MAE metrics: 0.09576288
# Epoch 247 PSNR metrics: 62.23298952680645 MAE metrics: 0.09416156
# Epoch 248 PSNR metrics: 62.226966562043714 MAE metrics: 0.09375019
# Epoch 249 PSNR metrics: 62.29565940333936 MAE metrics: 0.09539832

# %%
# print(PSNR)

# %%
# print(MAE)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.1, 0.1, 0.9, 0.9])
x_epoch = np.arange(EPOCHS)
# ax.plot(x_epoch, PSNR, 'r',label="PSNR")
ax.plot(x_epoch, MAE, 'b',label="MAE")
ax.set_xlabel("epoch")
ax.set_ylabel("metrics")
ax.legend()
plt.show()

# %%
tr1_test_data = load_images('/kaggle/input/d/jaquelinenoonan/mritestt1/') #write your code to create the dataset from image directory
tr1_test_data = tf.image.rgb_to_grayscale(tr1_test_data) #convert to grayscale
tr1_test= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr1_test_data))
tr1_test
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
tr2_test_data = load_images('/kaggle/input/d/jaquelinenoonan/mritestt2/') #write your code to create the dataset from image directory
tr2_test_data = tf.image.rgb_to_grayscale(tr2_test_data) #convert to grayscale
tr2_test= tf.data.Dataset.from_tensor_slices(tf.convert_to_tensor(tr2_test_data))
tr2_test
# Out:
# <TensorSliceDataset shapes: (256, 256, 1), types: tf.float32>

# %%
tr1_test = tr1_test.map(preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)
tr2_test = tr2_test.map(preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().batch(BATCH_SIZE)

# %%
# # Run the trained model on the train dataset
# iter_train = iter(tr2)
# for inp in tr1.take(5):  
#     sample_tr2 = iter_train.next()
#     generate_images(generator_g, inp, sample_tr2)

# %%
# Run the trained model on the test dataset
iter_test = iter(tr2_test)
j = 0
result = ['1', '2', '3', '4','5']
for inp in tr1_test.take(5):  
    sample_tr2_test = iter_test.next()
    prediction = generator_g(inp)
    plt.figure(figsize=(10, 10))
    display_list = [inp[0], prediction[0], sample_tr2_test[0]]
    title = ['Input Image', 'Predicted Image', 'Expected Image']
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off') 
    plt.savefig(result[j], dpi=300, bbox_inches = 'tight',pad_inches = 0)
    j = j+1
    img_metrics = metrics(generator_g, inp, sample_tr2_test)
    print('PSNR metrics:', img_metrics[0], 'MAE metrics:', img_metrics[1] )
# plt.savefig('test_result', dpi=300)
plt.show()
# fig=plt.gcf()
# Out:
# PSNR metrics: 57.92941435035955 MAE metrics: 0.16117154
# PSNR metrics: 57.149000157645276 MAE metrics: 0.20011961
# PSNR metrics: 54.98050238148487 MAE metrics: 0.28370687
# PSNR metrics: 57.7223904605325 MAE metrics: 0.16024509
# PSNR metrics: 60.37923641104981 MAE metrics: 0.13028221

# %%
# Run the trained model on the test dataset
iter_test = iter(tr1_test)
j = 0
result = ['1', '2', '3', '4','5']
for inp in tr2_test.take(5):  
    sample_tr1_test = iter_test.next()
    prediction = generator_f(inp)
    plt.figure(figsize=(10, 10))
    display_list = [inp[0], prediction[0], sample_tr1_test[0]]
    title = ['Input Image', 'Predicted Image', 'Expected Image']
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i].numpy()[:, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off') 
    plt.savefig(result[j], dpi=300, bbox_inches = 'tight',pad_inches = 0)
    j = j+1
    img_metrics = metrics(generator_f, inp, sample_tr1_test)
    print('PSNR metrics:', img_metrics[0], 'MAE metrics:', img_metrics[1] )
# plt.savefig('test_result', dpi=300)
plt.show()
# fig=plt.gcf()
# Out:
# PSNR metrics: 62.14012524444358 MAE metrics: 0.106641434
# PSNR metrics: 63.005535792161126 MAE metrics: 0.0963864
# PSNR metrics: 60.54436181392895 MAE metrics: 0.12911929
# PSNR metrics: 61.618821077063764 MAE metrics: 0.1061083
# PSNR metrics: 63.97594005720316 MAE metrics: 0.079688966

# %%
generator_g.save_weights('cycle_gengi.h5')

# %%
generator_f.save_weights('cycle_genfi.h5')
